# %%
import wrds
import pandas as pd
import numpy as np
import requests
import json
import os
import tqdm

# %%
db = wrds.Connection()
# Out:
# WRDS recommends setting up a .pgpass file.
# Created .pgpass file successfully.
# Loading library list...
# Done

# %%
# read in all_tickers.txt
with open('all_tickers.txt', 'r') as f:
    tickers = f.readlines()
tickers = [x.strip() for x in tickers]

# %%
tickers_compiled = ("A", "AACS", "AAIC", "AAIIQ", "AAL", "AAME", "AAM PR A", "AAN", "AAOI", "AAON", "AAP", "AAPL", "AASP", "AAT", "AATC", "AATV", "AAWW", "AB", "ABBB", "ABBY", "ABCB", "ABCP", "ABG", "ABLE", "ABM", "ABNB", "ABQQ", "ABR", "ABT", "AC", "ACA", "ACBCQ", "ACCO", "ACDC", "ACEL", "ACFN", "ACHR", "ACIW", "ACLS", "ACM", "ACMR", "ACMTA", "ACNB", "ACPS", "ACR", "ACRE", "ACRU", "ACT", "ACTG", "ACU", "ACVA", "ADBE", "ADC", "ADD", "ADEA", "ADEC", "ADFS", "ADGL", "ADGO", "ADI", "ADKT", "ADN", "ADP", "ADPT", "ADSK", "ADSV", "ADT", "ADTN", "ADVCD", "AE", "AEHR", "AEI", "AEIS", "AEL", "AENG", "AEO", "AERC", "AERG", "AERN", "AEVA", "AEY", "AEYE", "AFBI", "AFCG", "AFCL", "AFG", "AFHIF", "AFIIQ", "AFL", "AFRM", "AFTC", "AFTM", "AGAE", "AGCO", "AGDY", "AGFY", "AGIL", "AGM", "AGNC", "AGS", "AGTK", "AGX", "AGYS", "AHFI", "AHH", "AHT", "AI", "AIFM", "AIG", "AIMC", "AIN", "AINC", "AIP", "AIR", "AIRC", "AIRG", "AIRI", "AIRT", "AIT", "AIV", "AIZ", "AJG", "AJRD", "AJX", "AKA", "AKAM", "AKR", "AKTS", "AKVA", "AKYA", "AL", "ALBT", "ALBY", "ALEX", "ALFIQ", "ALG", "ALGM", "ALGT", "ALIT", "ALJJ", "ALK", "ALKT", "ALL", "ALLY", "ALMC", "ALME", "ALOD", "ALOT", "ALPE", "ALPIB", "ALPP", "ALRM", "ALRS", "ALSN", "ALTD", "ALTG", "ALTO", "ALTR", "ALTX", "ALX", "ALYI", "AM", "AMAL", "AMAT", "AMBA", "AMBC", "AMBK", "AMBZ", "AMD", "AME", "AMEN", "AMFC", "AMG", "AMH", "AMHG", "AMIN", "AMK", "AMKR", "AMLC", "AMMX", "AMNB", "AMOT", "AMP", "AMPG", "AMPL", "AMPX", "AMPY", "AMRA", "AMRC", "AMRK", "AMRT", "AMSC", "AMSF", "AMST", "AMSWA", "AMT", "AMTA", "AMTB", "AMTX", "AMTY", "AMV", "AMWD", "AMWK", "AMXX", "AMZN", "AN", "ANAS", "ANDC", "ANDR", "ANET", "ANF", "ANSS", "ANVV", "AOMR", "AOS", "AOSL", "AOUT", "AOXY", "APA", "APAM", "APCX", "APDN", "APEI", "APG", "APGI", "APGT", "APH", "APHD", "APHE", "APLD", "APLE", "APLN", "APO", "APOG", "APP", "APPF", "APPN", "APPS", "APPZ", "APTY", "APVS", "AQMS", "AQQSQ", "AQUA", "AR", "ARAO", "ARBV", "ARC", "ARC", "
# %%
# turn tickers, which is a list, into tuple
tickers_compiled = tuple(tickers)
#len(tickers_tuple)
#tickers_tuple

# %%
# CHANGE ME
# DATE RANGE
start_date = ('2015-01-01')
end_date = ('2023-03-01')

# %%
# DON'T CHANGE ME
params = {'tickers': tickers_compiled, 'start_date': start_date, 'end_date': end_date}

# %%
tables = db.list_tables("wrdsapps")
# check whether the table contains m_stock
#print(db.describe_table(library='wrdsapps_finratio', table='firm_ratio'))
#print(tables)
ratio_table = db.describe_table(library='wrdsapps_finratio', table='firm_ratio')

pd.set_option('display.max_rows', 98)
#ratio_table
# print out the value 
# ratio_table
# Out:
# Approximately 2782963 rows in wrdsapps_finratio.firm_ratio.

# %%
# Financial Ratios: change the first line in SELECT ...... to include more ratios
# start date and end date can be changed above

data_ratios = db.raw_sql(
    """
    SELECT PERMNO as PERMNO, gvkey as gvkey,TICKER, public_date as date, bm as book_to_market, 
    debt_assets, pe_inc as price_to_earnings, Accrual     
    FROM wrdsapps_finratio.firm_ratio 
    WHERE TICKER IN %(tickers)s AND public_date >= %(start_date)s AND public_date <= %(end_date)s
    """,
params=params)

# %%
data_ratios.shape
# Out:
# (256528, 8)

# %%
# company monthly stock data
data_price = db.raw_sql(
    """
    SELECT PERMNO as PERMNO,  Ticker as Ticker, MthCalDt as Date, ICBIndustry as ICB_industry_code, MthRet as monthly_return, sprtrn as snp_monthly_return, MthCap as monthly_mktcap, MthPrcVol as monthly_price_volume, ShrOut as shares_outstanding, MthPrc as monthly_price
    FROM crspm.wrds_msfv2_query
    WHERE Ticker in %(tickers)s AND MthCalDt >= %(start_date)s AND MthCalDt <= %(end_date)s
    """, 
    params=params)

# %%
data_price.shape
# Out:
# (439255, 10)

# %%
# Bonds
data_bond = db.raw_sql(
    """
    SELECT caldt as date, b10ret as ten_yr_YTM_rf
    FROM crspm.mcti
    WHERE caldt >= %(start_date)s AND caldt <= %(end_date)s
    """,
    params=params)

# %%
# ESG Data Processing
# read in ESG data
esg_score_raw = pd.read_excel('snpESG_all_ex.xlsx')

# %%
# get rid of the .0 in gvkey
esg_score_raw['gvkey'] = esg_score_raw['gvkey'].astype(str).str[:-2]

# %%
esg_score_raw
# Out:
#         institutionid Score Date                    Aspect Name  Score Value  \
# 0              100003 2017-04-19           S&P Global ESG Score           34
# 1              100003 2017-04-19  Economic Governance Dimension           50
# 2              100003 2017-04-19        Environmental Dimension           23
# 3              100003 2017-04-19               Social Dimension           21
# 4              100003 2017-04-19           S&P Global ESG Score           23
# ...               ...        ...                            ...          ...
# 166563      109851650 2023-02-17               Social Dimension           11
# 166564      109851650 2023-02-17           S&P Global ESG Score            8
# 166565      109851650 2023-02-17  Economic Governance Dimension           20
# 166566      109851650 2023-02-17        Environmental Dimension            0
# 166567      109851650 2023-02-17               Social Dimension            1
#
# ...

# %%
# re-arrange so that company id goes first, and ticker follows, the Score Data, Aspect Name, Socre Value, and institutionid
esg_score_raw = esg_score_raw[['gvkey', 'Company Name', 'Ticker', 'Score Date', 'Aspect Name', 'Score Value', 'institutionid']]
# Movie values of aspect name to columns
esg_score_raw = esg_score_raw.pivot_table(index=['gvkey','Company Name', 'Ticker', 'Score Date', 'institutionid'], columns='Aspect Name', values='Score Value')
# sort by score date
esg_score_raw = esg_score_raw.sort_values(by=['Score Date'])

# %%
esg_score_raw = esg_score_raw.sort_values(by=['Score Date'])
esg_score_finished = esg_score_raw.reset_index()
#esg_score_finished.head()

# %%
# check whether there are duplicates in esg_score_finished
esg_score_finished.duplicated().sum()
# for fama-french
#fama_french_betas.duplicated().sum()
# Out:
# 0

# %%
# rename Ticker to ticker, Score Date to date
esg_score_finished = esg_score_finished.rename(columns={'Ticker': 'ticker', 'Score Date': 'date'})
#esg_score_finished.head()

# %%
# merge ESG data with financial ratios based on ticker and date
# change the date column in data_price and data_ratios to date format
data_price['date'] = pd.to_datetime(data_price['date'])
data_ratios['date'] = pd.to_datetime(data_ratios['date'])

# merge data_price and data_ratios
data_price_ratios = pd.merge(data_price, data_ratios, on=['ticker', 'date', 'permno' ], how='inner')

# %%
# read in betas
fama_french_betas = pd.read_excel('fama_french_betas.xlsx')
capm_betas = pd.read_excel('capm_beta.xlsx')

# %%
data_bond['date'] = pd.to_datetime(data_bond['date'])
data_price_ratios['date'] = pd.to_datetime(data_price_ratios['date'])
esg_score_finished['date'] = pd.to_datetime(esg_score_finished['date'])
capm_betas['date'] = pd.to_datetime(capm_betas['date'])
fama_french_betas['date'] = pd.to_datetime(fama_french_betas['date'])
# in data_ratios, calculate shares_turnover, which is monthly_price_volume/shares_outstanding
data_price['shares_turnover'] = data_price['monthly_price_volume']/data_price['shares_outstanding']

# %%
# rename fama-french Ticker Symbol to ticker
fama_french_betas = fama_french_betas.rename(columns={'Ticker Symbol': 'ticker'})

# %%
# merge data_price_ratios and esg_score_finished
# change the date column in data_price_ratios and esg_score_finished to year-month-day format
data_price_ratios['date'] = data_price_ratios['date'].dt.strftime('%Y-%m')
esg_score_finished['date'] = esg_score_finished['date'].dt.strftime('%Y-%m')
data_bond['date'] = data_bond['date'].dt.strftime('%Y-%m')
capm_betas['date'] = capm_betas['date'].dt.strftime('%Y-%m')
fama_french_betas['date'] = fama_french_betas['date'].dt.strftime('%Y-%m')

# %%
type(esg_score_finished['gvkey'][0])
# change the type of gvkey in esg_score_finished to int
esg_score_finished['gvkey'] = esg_score_finished['gvkey'].astype(str)
# rename fama_french_betas PERMNO to permno
fama_french_betas = fama_french_betas.rename(columns={'PERMNO': 'permno'})
capm_betas = capm_betas.rename(columns={'PERMNO': 'permno'})

# %%
esg_score_finished['gvkey']
# Out:
# 0        128978
# 1        162401
# 2        128978
# 3        162401
# 4          1274
#           ...
# 19317      3153
# 19318     29382
# 19319     31521
# 19320      2986
# 19321     19295
# Name: gvkey, Length: 19322, dtype: object

# %%
data_price_ratios
# Out:
#          permno ticker     date icb_industry_code  monthly_return  \
# 0       10026.0   JJSF  2015-03           CONSTAP        0.058307
# 1       10032.0   PLXS  2015-03              TECH        0.012919
# 2       10044.0   RMCF  2015-03           CONSTAP       -0.085134
# 3       10104.0   ORCL  2015-03              TECH       -0.015290
# 4       10107.0   MSFT  2015-03              TECH       -0.072862
# ...         ...    ...      ...               ...             ...
# 178678  93397.0   LMNR  2022-11           CONSTAP        0.076278
# 178679  93423.0    SIX  2022-11            CONDIS        0.080269
# 178680  93426.0    VPG  2022-11              INDL        0.202074
# 178681  93434.0   SANW  2022-11           CONSTAP        0.121212
# 178682  93436.0   TSLA  2022-11            CONDIS       -0.144326
#
#         snp_monthly_return  monthly_mktcap  monthly_price_volume  \
# 0                -0.017396    1.994116e+06          1.953239e+08
# ...

# %%
esg_score_finished['gvkey']
# Out:
# 0        128978
# 1        162401
# 2        128978
# 3        162401
# 4          1274
#           ...
# 19317      3153
# 19318     29382
# 19319     31521
# 19320      2986
# 19321     19295
# Name: gvkey, Length: 19322, dtype: object

# %%
# merge data_price_ratios and esg_score_finished
data_incomplete = pd.merge(data_price_ratios, esg_score_finished, on=['ticker', 'date','gvkey'], how='right')
# drop company name and institutionid from data_incomplete
data_incomplete = data_incomplete.drop(['Company Name', 'institutionid'], axis=1)
data_complete = pd.merge(data_incomplete, data_bond, on=['date'], how='left')
# merge data_complete_missing_beta and fama_french_betas
# data_complete_missing_capm_beta = pd.merge(data_complete_missing_beta, fama_french_betas, on=['ticker', 'date', 'permno'], how='inner')
# merge data_complete_missing_beta and capm_betas
#data_complete = pd.merge(data_complete_missing_capm_beta, capm_betas, on=['ticker', 'date', 'permno'], how='inner')

# %%
# print the columns with the most NAs
data_complete.isna().sum().sort_values(ascending=False).head(20)
# Out:
# book_to_market                   17391
# price_to_earnings                17314
# accrual                          17308
# debt_assets                      17307
# permno                           17302
# shares_outstanding               17302
# monthly_price                    17302
# shares_turnover                  17302
# monthly_price_volume             17302
# monthly_mktcap                   17302
# snp_monthly_return               17302
# monthly_return                   17302
# icb_industry_code                17302
# ten_yr_ytm_rf                     1405
# ticker                               0
# gvkey                                0
# date                                 0
# Economic Governance Dimension        0
# Environmental Dimension              0
# S&P Global ESG Score                 0
# dtype: int64

# %%
# drop NA values
data_complete = data_complete.dropna()

# %%
data_complete.shape
# Out:
# (1916, 21)

# %%
data_complete
# Out:
#         permno ticker     date icb_industry_code  monthly_return  \
# 6      13318.0   YELP  2015-03              TECH       -0.013542
# 11     13511.0   PANW  2015-03              TECH        0.027141
# 14     87056.0   BMRN  2015-03            HEALTH        0.163911
# 15     92257.0    VMW  2015-03              TECH       -0.035970
# 23     13447.0    NOW  2015-03              TECH        0.033045
# ...        ...    ...      ...               ...             ...
# 17732  13641.0   FANG  2022-11            ENERGY       -0.044464
# 17733  13641.0   FANG  2022-11            ENERGY       -0.044464
# 17734  89216.0    AYI  2022-11              INDL        0.025712
# 17743  90312.0    WLK  2022-11            BASMAT        0.117553
# 17745  13407.0   META  2022-11              TECH        0.267711
#
#        snp_monthly_return  monthly_mktcap  monthly_price_volume  \
# 6               -0.017396    3.072542e+06          2.692096e+09
# ...

# %%
data_price_ratios.groupby('date')['permno'].nunique()
# Out:
# date
# 2015-03    2014
# 2015-04    2014
# 2015-06    2034
# 2015-07    2035
# 2015-08    2070
# 2015-09    2071
# 2015-11    2107
# 2015-12    2106
# 2016-02    2128
# 2016-03    2129
# 2016-05    2140
# 2016-06    2140
# 2016-08    2170
# 2016-09    2170
# 2016-10    2170
# 2016-11    2200
# 2017-01    2197
# 2017-02    2228
# 2017-03    2228
# 2017-05    2255
# 2017-06    2257
# 2017-07    2257
# 2017-08    2302
# 2017-10    2301
# 2017-11    2331
# 2018-01    2332
# 2018-02    2380
# 2018-04    2379
# 2018-05    2423
# 2018-07    2428
# 2018-08    2475
# 2018-10    2480
# 2018-11    2528
# 2018-12    2532
# 2019-01    2532
# 2019-02    2574
# 2019-04    2573
# 2019-05    2602
# 2019-07    2604
# 2019-09    2669
# 2019-10    2669
# 2019-12    2717
# 2020-01    2718
# 2020-03    2764
# 2020-04    2764
# 2020-06    2797
# 2020-07    2795
# 2020-08    2844
# 2020-09    2846
# 2020-11    2915
# 2020-12    2921
# 2021-03    3028
# 2021-04    3029
# 2021-06    3142
# 2021-08    3284
# ...

# %%
# count the number of companies per date in data_complete_missing_capm_beta
data_complete.groupby('date')['permno'].nunique()
# Out:
# date
# 2015-03     26
# 2015-09     45
# 2016-03     56
# 2016-09     63
# 2017-01      7
# 2017-07      1
# 2018-01      1
# 2018-02     10
# 2018-04     86
# 2018-05      1
# 2018-12      1
# 2019-02     32
# 2019-04      1
# 2019-05      3
# 2019-09     72
# 2019-12    198
# 2020-01     27
# 2020-03      1
# 2020-04     55
# 2020-06      1
# 2020-07      3
# 2020-11    154
# 2020-12    160
# 2021-03     14
# 2021-04      3
# 2021-11    246
# 2021-12     55
# 2022-01     47
# 2022-02     18
# 2022-03    107
# 2022-05      2
# 2022-06      1
# 2022-08      3
# 2022-09    225
# 2022-10     50
# 2022-11    139
# Name: permno, dtype: int64

# %%
data_complete.columns
# Out:
# Index(['permno', 'ticker', 'date', 'icb_industry_code', 'monthly_return',
#        'snp_monthly_return', 'monthly_mktcap', 'monthly_price_volume',
#        'shares_outstanding', 'monthly_price', 'shares_turnover', 'gvkey',
#        'book_to_market', 'debt_assets', 'price_to_earnings', 'accrual',
#        'Economic Governance Dimension', 'Environmental Dimension',
#        'S&P Global ESG Score', 'Social Dimension', 'ten_yr_ytm_rf'],
#       dtype='object')

# %%
# move 'Company Name' to the first column
cols = list(data_complete.columns.values)
cols.pop(cols.index('Company Name'))
data_complete = data_complete[['Company Name'] + cols]
# delete institutionid
data_complete = data_complete.drop(columns=['institutionid'])
data_complete.dropna(inplace=True)
# find the date that has the most number of companies
# data_complete['date'].value_counts()
# only keep the month that has the most number of companies
data_complete_2021_11 = data_complete[data_complete['date'] == '2021-11']
# drop the date column
data_complete_2021_11 = data_complete_2021_11.drop(columns=['date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/7f/zzvg3mdj425g3y3pzll4q80h0000gn/T/ipykernel_49051/3480305984.py in <module>
#       1 # move 'Company Name' to the first column
#       2 cols = list(data_complete.columns.values)
# ----> 3 cols.pop(cols.index('Company Name'))
#       4 data_complete = data_complete[['Company Name'] + cols]
#       5 # delete institutionid
#
# ValueError: 'Company Name' is not in list

# %%
# check if there are duplicated tickers
# print rows where cusip is duplicated
data_complete_2021_11[data_complete_2021_11.duplicated(['ticker'], keep=False)]
# delete rows where cusip is duplicated
# data_complete_2021_11_cusip_x = data_complete_2021_11.drop_duplicates(subset=['cusip_x'], keep='first')
# Out:
# Empty DataFrame
# Columns: [Company Name, icb_industry_code, monthly_return, snp_monthly_return, monthly_mktcap, monthly_price_volume, shares_outstanding, monthly_price, shares_turnover, gvkey, book_to_market, debt_assets, price_to_earnings, accrual, Economic Governance Dimension, Environmental Dimension, S&P Global ESG Score, Social Dimension, ten_yr_ytm_rf, b_mkt_fama_french_3fac, b_smb_fama_french_3fac, b_hml_fama_french_3fac, alpha_fama_french_3fac, excess_return_fama_french_3fac, permno, ticker, b_mkt_capm_mkt, alpha_capm, excess_return_capm]
# Index: []
#
# [0 rows x 29 columns]

# %%
# check whether there are duplicated tickers
data_complete_2021_11['ticker'].duplicated().any()
# Out:
# False

# %%
# find the duplicates
# print all rows here WSO is duplicated
data_complete_2021_11[data_complete_2021_11['ticker'] == 'WSO']
# Out:
# Empty DataFrame
# Columns: [Company Name, icb_industry_code, monthly_return, snp_monthly_return, monthly_mktcap, monthly_price_volume, shares_outstanding, monthly_price, shares_turnover, gvkey, book_to_market, debt_assets, price_to_earnings, accrual, Economic Governance Dimension, Environmental Dimension, S&P Global ESG Score, Social Dimension, ten_yr_ytm_rf, b_mkt_fama_french_3fac, b_smb_fama_french_3fac, b_hml_fama_french_3fac, alpha_fama_french_3fac, excess_return_fama_french_3fac, permno, ticker, b_mkt_capm_mkt, alpha_capm, excess_return_capm]
# Index: []
#
# [0 rows x 29 columns]

# %%
data_complete_2021_11
# Out:
# Empty DataFrame
# Columns: [Company Name, icb_industry_code, monthly_return, snp_monthly_return, monthly_mktcap, monthly_price_volume, shares_outstanding, monthly_price, shares_turnover, gvkey, book_to_market, debt_assets, price_to_earnings, accrual, Economic Governance Dimension, Environmental Dimension, S&P Global ESG Score, Social Dimension, ten_yr_ytm_rf, b_mkt_fama_french_3fac, b_smb_fama_french_3fac, b_hml_fama_french_3fac, alpha_fama_french_3fac, excess_return_fama_french_3fac, permno, ticker, b_mkt_capm_mkt, alpha_capm, excess_return_capm]
# Index: []
#
# [0 rows x 29 columns]

# %%
# find the date that has the most number of companies
print(data_complete['date'].value_counts())
# Out:
# Series([], Name: date, dtype: int64)

# %%
#data_price.to_excel('data_price.xlsx')

# %%
# export to excel
#data_ratios.to_excel('financial_ratios.xlsx', index=False)
#esg_score_finished.to_excel('ESG_Score_Processed.xlsx', index=False)
data_complete.to_excel('data_complete_2.xlsx', index=False)
#data_complete_2021_11.to_excel('data_complete_2021_11.xlsx', index=False)

# %%
data_complete
# Out:
# Empty DataFrame
# Columns: [Company Name, icb_industry_code, monthly_return, snp_monthly_return, monthly_mktcap, monthly_price_volume, shares_outstanding, monthly_price, shares_turnover, gvkey, book_to_market, debt_assets, price_to_earnings, accrual, Economic Governance Dimension, Environmental Dimension, S&P Global ESG Score, Social Dimension, ten_yr_ytm_rf, b_mkt_fama_french_3fac, b_smb_fama_french_3fac, b_hml_fama_french_3fac, alpha_fama_french_3fac, excess_return_fama_french_3fac, permno, date, ticker, b_mkt_capm_mkt, alpha_capm, excess_return_capm]
# Index: []
#
# [0 rows x 30 columns]

# %%
# rename the date column to year
data_complete = data_complete.rename(columns={'date': 'year'})

# for companies with the same PERMNO and gvkey and year, take the average across all values
data_complete = data_complete.groupby(['permno', 'gvkey', 'year']).mean().reset_index()

# %%
data_complete
# Out:
# Empty DataFrame
# Columns: [permno, gvkey, year, monthly_return, snp_monthly_return, monthly_mktcap, monthly_price_volume, shares_outstanding, monthly_price, shares_turnover, book_to_market, debt_assets, price_to_earnings, accrual, Economic Governance Dimension, Environmental Dimension, S&P Global ESG Score, Social Dimension, ten_yr_ytm_rf, b_mkt_fama_french_3fac, b_smb_fama_french_3fac, b_hml_fama_french_3fac, alpha_fama_french_3fac, excess_return_fama_french_3fac, b_mkt_capm_mkt, alpha_capm, excess_return_capm]
# Index: []
#
# [0 rows x 27 columns]

# %%
# export to excel

# %%
data_complete.columns
# Out:
# Index(['permno', 'gvkey', 'year', 'monthly_return', 'snp_monthly_return',
#        'monthly_mktcap', 'monthly_price_volume', 'shares_outstanding',
#        'monthly_price', 'shares_turnover', 'book_to_market', 'debt_assets',
#        'price_to_earnings', 'accrual', 'Economic Governance Dimension',
#        'Environmental Dimension', 'S&P Global ESG Score', 'Social Dimension',
#        'ten_yr_ytm_rf', 'b_mkt_fama_french_3fac', 'b_smb_fama_french_3fac',
#        'b_hml_fama_french_3fac', 'alpha_fama_french_3fac',
#        'excess_return_fama_french_3fac', 'b_mkt_capm_mkt', 'alpha_capm',
#        'excess_return_capm'],
#       dtype='object')

# %%
# DON't mind these data below, just for record keeping
# turn tickers_compiled into a dataframe
#tickers_compiled = pd.DataFrame(tickers_compiled)
# export to txt file
# tickers_compiled.to_excel('tickers_compiled.xlsx')
# VARIABLES 
# variables = ("TICKER", "public_date", "bm", "capital_ratio", "evm", "ptb", "roe")
# LIBRARY
# library = ('wrdsapps_finratio')
# Table
# table = ('firm_ratio')
# date_name
# date_name = ('public_date')
# ticker_name
# ticker_name = ('ticker')
# list tables 
# db.list_tables(library='wrdsapps_finratio')
# Find all the column names in the table
# print(db.describe_table(library='wrdsapps_finratio', table='firm_ratio'))
# Run the following code to see what the schema is for the for any tables in a library
data_test = db.raw_sql(
    """
    SELECT *
    FROM trucost.wrds_esg
    LIMIT 6
    """,
params=params)
data_test.columns()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1670
# -> 1671             context = constructor(
#    1672                 dialect, self, conn, execution_options, *args, **kw
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in _init_statement(cls, dialect, connection, dbapi_connection, execution_options, statement, parameters)
#    1140
# -> 1141         self.cursor = self.create_cursor()
#    1142         return self
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in create_cursor(self)
#    1342             self._is_server_side = False
# -> 1343             return self.create_default_cursor()
#    1344
#
# ...

# %%
# read in Final_data_yearly.xls

yearly_data = pd.read_excel('Final_data_yearly.xls')

# %%
yearly_data.head()
# Out:
#                     CompanyName ticker  year  institutionid  \
# 0    Agilent Technologies, Inc.      A  2019        4075849
# 1    Agilent Technologies, Inc.      A  2020        4075849
# 2    Agilent Technologies, Inc.      A  2021        4075849
# 3  American Airlines Group Inc.    AAL  2019        4065191
# 4  American Airlines Group Inc.    AAL  2020        4065191
#
#    EconomicGovernanceDimension  EnvironmentalDimension  SPGlobalESGScore  \
# 0                         51.0                    75.0              53.0
# 1                         47.0                    80.0              51.0
# 2                         50.0                    77.0              55.0
# 3                         43.5                    40.0              37.5
# 4                         57.0                    48.0              53.0
#
#    SocialDimension  PERMNO   gvkey  ...  b_mkt_fama_french_3fac1  \
# 0             50.0   87432  126554  ...                 4.321428
# ...

# %%
# check the shape of the data
yearly_data.shape
# Out:
# (3007, 30)

# %%
# only getting the 2021 data
yearly_data_2021 = yearly_data[yearly_data['year'] == 2021]

# %%
## Regression
# first, add a constant in our matrix
df_spread = sm.add_constant(df_spread)
df_spread.head()

# run the regression
model = sm.OLS(df_spread['Ri-Rf'], df_spread[['const', 'Rm-Rf', 'SMB', 'HML', 'ESG']])

# get the results
results = model.fit()

## Results
print(results.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/7f/zzvg3mdj425g3y3pzll4q80h0000gn/T/ipykernel_56067/954467263.py in <module>
#       1 ## Regression
#       2 # first, add a constant in our matrix
# ----> 3 df_spread = sm.add_constant(df_spread)
#       4 df_spread.head()
#       5
#
# NameError: name 'df_spread' is not defined

# %%
yearly_data_2021.columns
# Out:
# Index(['CompanyName', 'ticker', 'year', 'institutionid',
#        'EconomicGovernanceDimension', 'EnvironmentalDimension',
#        'SPGlobalESGScore', 'SocialDimension', 'PERMNO', 'gvkey',
#        'book_to_market1', 'capital_ratio1', 'enterprise_value_multiple1',
#        'price_to_book1', 'return_on_equity1', 'inventory_current_asset_frac1',
#        'receivable_current_asset_frac1', 'cash_ratio1', 'effective_tax_rate1',
#        'debt_assets1', 'b_mkt_fama_french_3fac1', 'b_smb_fama_french_3fac1',
#        'b_hml_fama_french_3fac1', 'alpha_fama_french_3fac1',
#        'excess_return_fama_french_3fac1', 'permno', 'icb_industry_code',
#        'mktcap', 'yearly_return', 'industry'],
#       dtype='object')

# %%
# run a regression 
# import statsmodels.api as sm
# With mktcap, book_to_market1, b_mkt_fama_french_3fac1, SPGlobalESGScore, and interaction between icb_industry_code and SPGlobalESGScore
# dependent variable is yearly_return

import statsmodels.api as sm
import statsmodels.formula.api as smf

# run a regression
# with mktcap, book_to_market1, b_mkt_fama_french_3fac1, SPGlobalESGScore, and interaction between icb_industry_code and SPGlobalESGScore
# dependent variable is yearly_return
model = smf.ols(formula='yearly_return ~ b_mkt_fama_french_3fac1 + mktcap + book_to_market1 + SPGlobalESGScore + icb_industry_code:SPGlobalESGScore', data=yearly_data_2021)
results = model.fit()


# output the results and export to pdf
print(results.summary())
results.summary().as_latex()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          yearly_return   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     4.619
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):           3.40e-08
# Time:                        23:26:04   Log-Likelihood:                -648.63
# No. Observations:                1023   AIC:                             1327.
# Df Residuals:                    1008   BIC:                             1401.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# ...

# %%
# correlation matrix
corr = yearly_data_2021.corr()
corr
# Out:
#                                  year  institutionid  \
# year                              NaN            NaN
# institutionid                     NaN       1.000000
# EconomicGovernanceDimension       NaN      -0.109392
# EnvironmentalDimension            NaN      -0.097317
# SPGlobalESGScore                  NaN      -0.126178
# SocialDimension                   NaN      -0.105919
# PERMNO                            NaN      -0.160954
# gvkey                             NaN       0.069424
# book_to_market1                   NaN      -0.192981
# capital_ratio1                    NaN       0.033026
# enterprise_value_multiple1        NaN       0.001098
# price_to_book1                    NaN       0.165452
# return_on_equity1                 NaN      -0.001304
# inventory_current_asset_frac1     NaN       0.021520
# receivable_current_asset_frac1    NaN      -0.084448
# cash_ratio1                       NaN       0.021943
# effective_tax_rate1               NaN       0.019155
# ...

# %%
data_complete.columns
# Out:
# Index(['Company Name', 'PERMNO', 'ticker', 'date', 'icb_industry_code',
#        'monthly_return', 'snp_monthly_return', 'monthly_mktcap',
#        'monthly_price_volume', 'gvkey', 'book_to_market', 'capital_ratio',
#        'enterprise_value_multiple', 'price_to_book', 'return_on_equity',
#        'inventory_current_asset_frac', 'receivable_current_asset_frac',
#        'cash_ratio', 'effective_tax_rate', 'debt_assets',
#        'Economic Governance Dimension', 'Environmental Dimension',
#        'S&P Global ESG Score', 'Social Dimension', 'ten_yr_ytm_rf',
#        'b_mkt_fama_french_3fac', 'b_smb_fama_french_3fac',
#        'b_hml_fama_french_3fac', 'alpha_fama_french_3fac',
#        'excess_return_fama_french_3fac', 'b_mkt_capm_mkt', 'alpha_capm',
#        'excess_return_capm'],
#       dtype='object')

# %%
# read in data_complete.xlsx

data_complete = pd.read_excel('data_complete.xlsx')
data_analysis = pd.read_excel('Final_data_yearly.xls')
data_complete.rename(columns={'permno': 'PERMNO'}, inplace=True)
# join the b_mkt_capm_mkt from data_complete to data_analysis on PERMNO and gvkey
data_analysis_beta = data_analysis.merge(data_complete[['PERMNO', 'gvkey', 'b_mkt_capm_mkt']], on=['PERMNO', 'gvkey'], how='left')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/7f/zzvg3mdj425g3y3pzll4q80h0000gn/T/ipykernel_49051/3078405982.py in <module>
#       1 # read in data_complete.xlsx
#       2
# ----> 3 data_complete = pd.read_excel('data_complete.xlsx')
#       4 data_analysis = pd.read_excel('Final_data_yearly.xls')
#       5 data_complete.rename(columns={'permno': 'PERMNO'}, inplace=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data_analysis_beta.shape
data_analysis_beta.to_excel('data_analysis_beta.xlsx')

# %%
# for company with the same year and same PERMNO and gvkey, take the average of all the variables
data_complete_monthly = data_analysis_beta.groupby(['PERMNO', 'gvkey', 'date']).mean().reset_index()
